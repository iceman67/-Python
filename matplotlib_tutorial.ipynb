# %% [markdown]
# <a href="https://colab.research.google.com/github/iceman67/-Python/blob/master/matplotlib_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **데이터시각화**
# * 데이터 시각화는 데이터 수집내용과 분석을 연결해주는 역할 수행함
# * 그림이 아닌것을 그림으로 바꾸는 작업
# * 숫자의 패턴과 의미를 파악하는 방법을 데이터 시각화임
#
# **데이터  시각화 필요성**
# * 데이터 이해도 증진
# * 새로운 특징 탐색
# * 데이터문제점 도출
# * 전체와 부분을 동시 이해하기 위해  사용
#
# [파이썬 패키지 중 대표적인 시각화 패지지는 무엇인가 ? ](https://www.kdnuggets.com/wp-content/uploads/top-python-libs-ds-viz-ml-header.png)
# > 파이썬의 대표적인 시각화 도구는 matplotlib과 seaborn 임
#
#
# **Matplotlib**
#
# *  파이썬에서 데이타를 차트나 플롯(Plot)으로 그려주는 라이브러리 패키지 (데이터 시각화)
# *  매트랩(Matlab)과 유사한 그래프 표시를 가능케 함
# *  numpy나 pandas에서 사용되는 자료구조를 쉽게 시각화
# *  라인 플롯, 바 차트, 파이차트, 히스토그램, 박스 플롯, Scatter 플롯 (산포도)
#
# **Matplotlib 사용하기**
#
# * matplotlib.pyplot 를 import
# * plt를 alias로 사용
# * plot()를 사용 라인 플롯 수행함

# %%
# !pip3 install matplotlib

# %% [markdown]
# * matplotlib의 가장 기본적인 시각화 명령은 plot() 임
# * 데이터를 line plot으로 표현하는 명령
# * 여러 옵션을 사용하여 다양한 시각화가 가능함

# %% [markdown]
# #### 데이터분석 결과 시각화 시작하기

# %%
import pandas as pd 

data = {
    "city": ["Seoul", "Seoul", "Seoul", "Busan", "Busan", "Busan", "Incheon", "Incheon"],
    "year": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "population": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
}
columns = ["city", "year", "population"]
df = pd.DataFrame(data=data, columns=columns)
df
# Out:
#       city  year  population
# 0    Seoul  2015     9904312
# 1    Seoul  2010     9631482
# 2    Seoul  2005     9762546
# 3    Busan  2015     3448737
# 4    Busan  2010     3393191
# 5    Busan  2005     3512547
# 6  Incheon  2015     2890451
# 7  Incheon  2010      263203

# %%
grouped = df.groupby('city')['population'].sum()

# %%
grouped
# Out:
# city
# Busan      10354475
# Incheon     3153654
# Seoul      29298340
# Name: population, dtype: int64

# %%
grouped.plot(kind='bar')
plt.xlabel('city')
plt.ylabel('population')
plt.show()

# %% [markdown]
# * 그룹핑 결과에서 인덱스를 초기화하여 시각화하기

# %%
grouped = df.groupby('city')['population'].sum().reset_index()
grouped.plot(kind='bar')
plt.ylabel('population')
plt.show()

# %%
grouped
# Out:
#       city  population
# 0    Busan    10354475
# 1  Incheon     3153654
# 2    Seoul    29298340

# %% [markdown]
# * seaborn을 사용한 자료 시각화
# > 도시별 자료값의 차이를 이해하기 쉬움

# %%
g=sns.barplot(x='city',y='population',data=grouped, palette="Blues")

# %%
grouped = df.groupby('year')['population'].sum().reset_index()
g=sns.barplot(x='year',y='population',data=grouped)

# %% [markdown]
# ### 타이타닉호 데이터셋 분석 결과 시각화하기

# %%
url = 'https://raw.githubusercontent.com/iceman67/DataAnalysis/master/train.csv'
titanic_df = pd.read_csv(url)

# %%
data = titanic_df['Sex'].value_counts()
data.plot(kind='bar')

# %%
grouped = titanic_df.groupby('Pclass') ['Survived'].mean()
grouped.plot(kind='bar')

# %%
grouped.plot(kind='pie')

# %% [markdown]
# * matplotlib 으로 시각화하기

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# * 리스트 자료값 [1,2,3,4]를 y 값으로 하여 화면에 플롯팅을 함
# * x 값의 범위를 생락할 수 있음, 디폴트 값으로 [0, 1,2,... n] 으로 설정되며 n은 y 값의 계수에 의해 결정됨

# %%
plt.plot([1,2,3,4])

# %% [markdown]
# * x 축과 y 축의 값을 지정함

# %%
x = [1, 2, 3, 4]
y = [5, 4, 5, 3]

# %%
#  figure를 2x3 그리드로 나눈다
plt.plot(x,y)

# %% [markdown]
# * x축과 y축의 레이블을 지정하여 그래프를 그림

# %%
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x,y)

# %% [markdown]
# * x 축의 구간은 0에서 9까지의 값으로 지정
# * $y = x^2$ 함수를 시각화함

# %%
x = np.arange(10)
plt.plot (x**2)

# %% [markdown]
# * plt.axis() 를 사용하여 $x$축 범위와 $y$축 범위를 지정함
# > x값이 증가할 때 y값이 가파르게 증가됨을 보임

# %%
x = np.arange(10)
plt.plot (x**2)
plt.axis ([0,100, 0,100])
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# * 라인의 스타일을 지정하기 위한 마커(marker)를 지정할 수 있음
# >  예, 실선(-), 점선(:), 일점선(-.), 끊어진 실선(--)
#
# * 마커로 o 을 지정하는 경우 보여지는 결과를 확인함

# %%
plt.plot( [1, 2, 3, 4],  [1, 2, 3, 4], "ro")

# %% [markdown]
# * figure 객체의 savefig() 메소드를 사용하여 이미지로 저장
# > png 파일 형식 지정
#
# * colab 의 파일탭을 통해 저정된 파일을 확인함

# %%
# 사인 함수

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
# -pi부터 pi까지 균일하게 분포된 256개의 점을 생성
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
#x = [m for m in range(0,100)]

y = np.sin(x)
plt.plot(x,y, 'r-')

fig.savefig("sine_fig.png")

# %% [markdown]
# * 2개의 함수 sin()과 cos() 의 주기함수를 사용하여 시각화

# %%
# 사인 코사인 함수

import matplotlib.pyplot as plt
import numpy as np

 
# -pi부터 pi까지 균일하게 분포된 20개의 점을 생성
x = np.linspace(-np.pi, np.pi, 20, endpoint=True)
#x = [m for m in range(0,100)]

y = np.sin(x)
plt.plot(x,y, 'g^:')  # 녹색, 점선, 삼각형의 표식 사용
y1 = np.cos(x)
plt.plot(x,y1, 'b:')  # 파란, 점선 표식 사용

# %% [markdown]
# * 제목, 레이블, 범례 추가하기

# %%
# 사인 코사인 함수

import matplotlib.pyplot as plt
import numpy as np

 
# -pi부터 pi까지 균일하게 분포된 20개의 점을 생성
x = np.linspace(-np.pi, np.pi, 20, endpoint=True)
#x = [m for m in range(0,100)]

y = np.sin(x)
plt.plot(x,y, 'g^:', label="sin function")  # 녹색, 점선, 삼각형의 표식 사용
y1 = np.cos(x)
plt.plot(x,y1, 'b:', label="cos function")  # 파란, 점선 표식 사용
plt.legend()

# %%
# 사인 코사인 함수

import matplotlib.pyplot as plt
import numpy as np

 
# -pi부터 pi까지 균일하게 분포된 20개의 점을 생성
x = np.linspace(-np.pi, np.pi, 20, endpoint=True)
#x = [m for m in range(0,100)]

y = np.sin(x)
plt.plot(x,y, 'g^:', label="sin function")  # 녹색, 점선, 삼각형의 표식 사용
y1 = np.cos(x)
plt.plot(x,y1, 'b:', label="cos function")  # 파란, 점선 표식 사용
plt.xlabel ("x value")
plt.ylabel ("y value")
plt.legend()

# %% [markdown]
# * 다양한 종류의 그래프 표현하기

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
# 누적 막대그래프
plt.bar(x,y,  color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
# 수평 막대그래프
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(x,y)
plt.show()

# %%
y1 = [7,8,5,3]
plt.bar(x,y1, bottom=y, color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
# 사인 함수

import matplotlib.pyplot as plt
import numpy as np

# -pi부터 pi까지 균일하게 분포된 256개의 점을 생성
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
#x = [m for m in range(0,100)]

y = np.sin(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# [numpy 배열 시각화하기](https://colab.research.google.com/drive/12DlcKC1pGc4BF_8Gnl9Ej2F22IKVBbU1)

# %% [markdown]
# * plt.plot([x축 데이터], [y축 데이터]) 의 형식으로 사용
# * x축 데이터, y축 데이터 는 list 형 자료임
# * 각 x좌표의 y지점에 점을 찍어 연결한 그래프로 표현
# * 기본적으로 '선 그래프'로 그려짐

# %% [markdown]
# * $y=x^2$ (x>=0) 그래프
#
# > 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)

# %%
x = range(0, 20)
y = [v*v for v in x]
#plt.plot(x, y)
plt.title('$y=x^2$')
plt.plot(x, y, 'r+')

# %% [markdown]
# * 그래프에 (x, y) 좌표에 점을 표현하고 싶으면  marker 인자를 추가
# > 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
# marker 인자를 같이 적는다.
plt.plot([1,2,3], [1,2,3], marker='+')

plt.show()

# %% [markdown]
# **실습**
#  * marker를  * 로 변경하여 시각화 결과를 확인한다
#  * 사용가능한 marker 를 찾아 변경해 본다
#
#  (참고) https://matplotlib.org/api/markers_api.html

# %%
# marker 인자를 같이 적는다.
plt.plot([1,2,3], [1,2,3], marker='o')

plt.show()

# %% [markdown]
# **scatter 그래프**

# %%
# plt.scatter([x축 데이터], [y축 데이터]) 를 사용
# (1,1), (2,2), (3,3) 에 점을 찍은 그래프를 그린다.
plt.scatter([1,2,3], [1,2,3])

plt.show()

# %%
import numpy as np
# x 축 [1,2,3]
# y 축 [4,500,9000]
data = np.array([[1,2,3],[4,500,9000]])
plt.scatter(data[0,:], data[1,:])


plt.plot(data[0,:], data[1,:])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.bar(data[0,:], data[1,:])
plt.plot(data[0,:], data[1,:])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.bar(data[0,:], data[1,:])
plt.plot(data[0,:], data[1,:])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.yscale("log")
plt.show()

# %% [markdown]
# **막대 그래프**

# %%
plt.figure()

# 각 x축 데이터 지점에 y축 데이터의 길이의 막대를 그린다.
plt.bar([1,2,3], [1,2,3])

plt.show()

# %% [markdown]
# **파이 그래프**

# %%
plt.figure()

# 데이터 비율이 1:2:3 인 파이 그래프를 그린다.
plt.pie([1,2,3])

plt.show()

# %% [markdown]
# ### 여러개의 그래프 그리기
#
# * plt.subplots(행, 열) 를 사용
# * plt.subplots(행, 열) 은 2개의 변수를 반환 (전체 액자 figure에 대한 변수, 액자 내 여러개의 액자에 대한 리스트 axs)

# %%
fig, ax = plt.subplots(2, 2)

x = np.random.randn(100)
y = np.random.randn(100)
ax[0,0].scatter(x,y)

x = np.arange(10)
y = np.random.uniform(1,10,10)
ax[0,1].bar(x,y)

x = np.linspace(0,10,100)
y = np.sin(x)
ax[1,0].plot(x,y)  

z = np.random.uniform(0, 1, (5,5))
ax[1,1].imshow(z)

# %%
# figure 사용,  그래프를 표현할 액자를 먼저 만든다.
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 5))
# 
ax1 = fig.add_subplot(2, 1, 1) #  (2, 1, 1)은 2x1(행x열)의 subplot
# (1,1), (2,2), (3,3) 의 데이터를 넣어서 그린다.
ax1.plot([1,2,3], [1,2,3], 'r')

ax2 = fig.add_subplot(2, 1, 2) # (2, 1, 2)는 2x1 subplot에서 두 번째 subplo
ax2.plot([1,2,3], [1,4,9], 'g')
# figure 를 출력한다.
plt.show()

# %%
# figure 사용,  그래프를 표현할 액자를 먼저 만든다.
import matplotlib.pyplot as plt
fig = plt.figure()
# 
ax1 = fig.add_subplot(1, 2, 1) #  (2, 1, 1)은 2x1(행x열)의 subplot
# (1,1), (2,2), (3,3) 의 데이터를 넣어서 그린다.
ax1.plot([1,2,3], [1,2,3], 'r')

ax2 = fig.add_subplot(1, 2, 2) # (2, 1, 2)는 2x1 subplot에서 두 번째 subplo
ax2.plot([1,2,3], [1,4,9], 'g')
# figure 를 출력한다.
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

x = range(0, 100)
y = [v*v for v in x]

ax1.plot(x, y)
ax2.bar(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1) 
linear_data = np.array([1,2,3,4,5])
ax1.plot(linear_data, '-o')

exponential_data = linear_data ** 2
ax2 = fig.add_subplot(1, 2, 2) 
ax2.plot(exponential_data, '-o')

# %%
ax1 = plt.subplot(1, 2,1)
linear_data = np.array([1,2,3,4,5])
ax1.plot(linear_data, '-o')
exponential_data = linear_data ** 2
ax2 = plt.subplot(1,2,2,  sharey=ax1)
ax2.plot(exponential_data, '-x')
# ax1에 그래프 추가
ax1.plot(exponential_data, '-x')

# %%
# 1행 3열로 액자들을 그린다.
fig, ax = plt.subplots(1, 3)

# 각 액자들에 그래프를 그린다.
ax[0].plot([1,2,3],[1,2,3], )
ax[1].bar([1,2,3],[1,2,3])
ax[2].pie([1,2,3])

plt.show()

# %% [markdown]
# ### 그래프 크기 변경
#
# * plt.figure() 안에 figsize=(가로 길이, 세로 길이) 인자를 지정함

# %%
plt.figure(figsize=(20, 5))
plt.plot([1,2,3], [1,2,3], marker='o')
plt.show()

# %%
# 가로20, 세로10인 큰 액자 안에, 1행 3열로 액자들을 그린다.
fig, ax = plt.subplots(1, 3, figsize=(20, 5))

# 각 액자들에 그래프를 그린다.
ax[0].plot([1,2,3],[1,2,3], )
ax[1].bar([1,2,3],[1,2,3])
ax[2].pie([1,2,3])

plt.show()

# %% [markdown]
# * set_xlabel과 set_ylabel 메서드를 이용해 subplot의 x축과 y축에 라벨을 추가

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)

fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')

ax1.set_xlabel('x')
ax1.set_ylabel('sin(x)')

ax2.set_xlabel('x')
ax2.set_ylabel('cos(x)')

plt.show()

# %% [markdown]
# ### Pandas 자료 구조를 사용한 matplotlib 시각화

# %%
import pandas as pd
# Series를 통한 line plot 그리기
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s

# %%
s.shape
# Out:
# (10,)

# %%
# Series s의 index와 value를 X와 Y 축 값으로  플롯 
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   2.131901 -1.932439 -0.925604 -1.376574
# 10  2.396195 -2.727040 -0.859715 -2.239077
# 20  2.245986 -4.220887 -1.334666 -4.367116
# 30  4.021430 -4.220563  0.571352 -5.275236
# 40  3.570069 -4.618857  0.381437 -5.346399
# 50  3.004460 -4.466031 -0.814112 -5.581487
# 60  0.792873 -4.594760  0.105003 -3.973032
# 70  0.133630 -6.138980 -0.249677 -3.421090
# 80  0.099023 -6.823824 -2.321386 -1.625983
# 90  2.093453 -5.290576 -2.900596 -2.176932

# %%
df.plot()

# %%
# 특정 열을 플롯함
df['B'].plot()

# %% [markdown]
# **(실습)간단한 그래프그리기**

# %%
from matplotlib import pyplot as plt
 
plt.plot([1,2,3], [110,130,120])
plt.show()

# %%
from matplotlib import pyplot as plt

# 스타일 구성
plt.plot([1,2,3], [110,130,120], color = 'r', marker='o')
plt.show()

# %%
plt.plot(np.random.randn(50), color = 'g', marker='o', linestyle='--')

# %% [markdown]
# **축 레이블 및 제목 붙이기**
#
# * X,Y 축 레이블이나 제목을 붙이기 위해서는 plt.xlabel(축이름), plt.ylabel(축이름), plt.title(제목) 등의 함수를 사용

# %%
from matplotlib import pyplot as plt
 
plt.plot([1,2,3], [110,130,120])


plt.xlabel('X')
plt.ylabel('Y')
plt.title('Experiment Result')
plt.show()

# %%
from matplotlib import pyplot as plt
 
plt.scatter([1,2,3], [110,130,120])


plt.xlabel('X')
plt.ylabel('Y')
plt.title('Experiment Result')
plt.show()

# %%
#한글 지정시 (자신의 PC에서 활용)
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
#  **범례 추가**

# %%
import matplotlib.pyplot as plt
 
plt.plot([1,2,3], [1,4,9])
plt.plot([2,3,4],[5,6,7])
plt.xlabel('Sequence')
plt.ylabel('Time(secs)')
plt.title('Experiment Result')
plt.legend(['Mouse', 'Cat'])
plt.show()

# %% [markdown]
# **바 차트**
#
# (문제) X 축과 Y축의 레이블을 추가한다.

# %%
from matplotlib import pyplot as plt
 
y = [5, 3, 7, 10, 9, 5, 3.5, 8]
x = range(len(y))
plt.bar(x, y, width=0.7, color="blue")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# **라인플롯**

# %%
import matplotlib.pyplot as plt
y = [5, 3, 7, 10, 9, 5, 3.5, 8]
x = range(len(y))

plt.plot(x,y)
plt.show()

# %%
year=[1950,1970,1990,2010]
pop=[2.519,3.692,5.236,6.972]
plt.plot(year,pop)
plt.show()

# %% [markdown]
# **2007 년 국제 통계조사 시각화하기**

# %%
import pandas as pd
csv_file='https://assets.datacamp.com/production/repositories/287/datasets/5b1e4356f9fa5b5ce32e9bd2b75c777284819cca/gapminder.csv'

df = pd.read_csv(csv_file)

# %% [markdown]
# **Scatter 플롯**
# * 라인플롯으로 의미파악이 어려운 경우
# * x변수와 y변수의 상관관계를 표시할 때 사용

# %%
import matplotlib.pyplot as plt
# Change the line plot below to a scatter plot
plt.plot(df['gdp_cap'], df['life_exp'])
plt.xlabel('GDP')
plt.ylabel('Life exp')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
# Change the line plot below to a scatter plot
plt.scatter(df['gdp_cap'], df['life_exp'])
plt.xlabel('GDP')
plt.ylabel('Life exp')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
# Change the line plot below to a scatter plot
plt.scatter(df['gdp_cap'], df['life_exp'])
# Put the x-axis on a logarithmic scale
plt.xlabel('GDP')
plt.ylabel('Life exp')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.xscale('log')
# Show plot
plt.show()

# %%
import numpy as np

gdp_cap = df["gdp_cap"].tolist()
life_exp = df["life_exp"].tolist()

pop = df["population"].tolist()
pop_np = np.array(pop)


#plt.scatter(gdp_cap, life_exp, s = pop_np*2/1000000)
plt.scatter(gdp_cap, life_exp, s=df.population/1e6)
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]') 
plt.ylabel('Life Expectancy [in years]') 
plt.title('World Development in 2007') 
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.show()

# %%
col=['red','green','blue','blue','yellow','black','green','red','red','green','blue','yellow','green','blue','yellow','green','blue','blue','red','blue','yellow','blue','blue','yellow','red','yellow','blue','blue','blue','yellow','blue','green','yellow','green','green','blue','yellow','yellow','blue','yellow','blue','blue','blue','green','green','blue','blue','green','blue','green','yellow','blue','blue','yellow','yellow','red','green','green','red','red','red','red','green','red','green','yellow','red','red','blue','red','red','red','red','blue','blue','blue','blue','blue','red','blue','blue','blue','yellow','red','green','blue','blue','red','blue','red','green','black','yellow','blue','blue','green','red','red','yellow','yellow','yellow','red','green','green','yellow','blue','green','blue','blue','red','blue','green','blue','red','green','green','blue','blue','green','red','blue','blue','green','green','red','red','blue','red','blue','yellow','blue','green','blue','green','yellow','yellow','yellow','red','red','red','blue','blue']

# Specify c and alpha inside plt.scatter()
plt.scatter(gdp_cap,life_exp, s=df.population*0.000001,c=col,alpha=0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Show the plot
plt.show()

# %%
# Scatter plot
plt.scatter(x = gdp_cap, y = life_exp,s=df.population*0.000001, c = col, alpha = 0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# **바 차트 사용**
# * 특정 변수의 distribution을 확인할 때

# %%
import matplotlib.pyplot as plt
# Create histogram of life_exp data
plt.hist(df['life_exp'])
# Display histogram
plt.show()

# %%
# Build histogram with 5 bins
plt.hist(df['life_exp'],bins=5)
# Show and clean up plot
plt.show()
plt.clf()
# Build histogram with 20 bins
plt.hist(df['life_exp'],bins=20)
# Show and clean up again
plt.show()
plt.clf()

# %% [markdown]
# **barh 차트**

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['INFO', 'CUISINE', 'TYPE_OF_PLACE', 'DRINK', 'PLACE', 'MEAL_TIME', 'DISH', 'NEIGHBOURHOOD']
y = [160, 167, 137, 18, 120, 36, 155, 130]

fig, ax = plt.subplots()    
width = 0.75 # the width of the bars 
ind = np.arange(len(y))  # the x locations for the groups
ax.barh(ind, y, width, color="blue")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(x, minor=False)
plt.title('title')
plt.xlabel('x')
plt.ylabel('y')      
plt.show()
#plt.savefig(os.path.join('test.png'), dpi=300, format='png', bbox_inches='tight') # use format='svg' or 'pdf' for vectorial pictures

# %%
import numpy as np
import matplotlib.pyplot as plt

x = ['INFO', 'CUISINE', 'TYPE_OF_PLACE', 'DRINK', 'PLACE', 'MEAL_TIME', 'DISH', 'NEIGHBOURHOOD']
y = [160, 167, 137, 18, 120, 36, 155, 130]

fig, ax = plt.subplots()    
width = 0.75 # the width of the bars 
ind = np.arange(len(y))  # the x locations for the groups
ax.barh(ind, y, width, color="blue")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(x, minor=False)

for i, v in enumerate(y):
    ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')

plt.title('title')
plt.xlabel('x')
plt.ylabel('y')      
plt.show()

# %% [markdown]
# ### 개방데이터를 활용한 시각화 실습

# %%
#라이브러리 임포트
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

#seaborn에서 제공하는 flights 데이터 셋을 사용
flights = sns.load_dataset('flights')

#그래프 사이즈 설정
plt.figure(figsize=(12, 3))

# %% [markdown]
# * 생성된 데이터프레임의 통계값을 살펴본다
# * 생성된 데이터 프레임의 컬럼간의 상관관계를 살펴본다
# * 상관관계를 시각화한후 확인한다

# %%
flights.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %% [markdown]
# * 자료값을 막대그래프 (bar chart)로 표현

# %%
plt.bar(flights['year'], flights['passengers'])
# Out:
# <BarContainer object of 144 artists>

# %%
plt.bar(flights['year'], flights['passengers'])
plt.xlabel ("Year")
plt.ylabel ("# of passengers")
# Out:
# Text(0, 0.5, '# of passengers')

# %%
sns.barplot(data=flights, x="year", y="passengers")

# %%
sns.boxplot(data=flights, x="year", y="passengers")

# %% [markdown]
# * [IMDB](https://colab.research.google.com/drive/1sBSSavSMBjpWB6ARbjiKnP8xLorfiSUt)
# * [MovieTrend](https://colab.research.google.com/drive/1FVYnvaX5313Ru-H-m-wvEEiZ5zh2iyFl)
# * [KOBIS boxoffices](https://colab.research.google.com/drive/1qxqIZZaRV34uqa_uZFuS8Ig-sy91ZMh-)

# %% [markdown]
# **(참고)**
#
# * https://towardsdatascience.com/data-visualization-using-matplotlib-16f1aae5ce70
# * https://dailyheumsi.tistory.com/36
